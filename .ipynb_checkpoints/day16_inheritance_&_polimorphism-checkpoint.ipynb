# %% [markdown]
# ### Class Relationships
#
# - Aggregation
# - Inheritance

# %% [markdown]
# # aggregation(has a relationship)
# ##### Aggregation is a “has-a” relationship where one class contains a reference to another class, but both objects can exist independently

# %%
 class Customer:
     def __init__(self, name, gender,address):
         self.name = name
         self.gender = gender
         self.address = address
     def print_address(self):
         print(self.address.city, self.address.pin, self.address.state)
class Address:
    def __init__(self,city,pin,state):
        self.city = city
        self.pin = pin
        self.state = state
    

add1 = Address('rajgopal', 229219,'up')
cust = Customer('prasant','male',add1)

# %%
cust.print_address()
# Out:
# rajgopal 229219 up

# %%
cust.gender
# Out:
# 'male'

# %%
class Customer:
     def __init__(self, name, gender,address):
         self.name = name
         self.gender = gender
         self.address = address
     def print_address(self):
         print(self.address.get_city(), self.address.pin, self.address.state)
class Address:
    def __init__(self,city,pin,state):
        self.__city = city
        self.pin = pin
        self.state = state
    def get_city(self):
        return self.__city

add1 = Address('rajgopal', 229219,'up')
cust = Customer('prasant','male',add1)

# %%
cust.print_address()
# Out:
# rajgopal 229219 up

# %%
class Customer:
     def __init__(self, name, gender,address):
         self.name = name
         self.gender = gender
         self.address = address
     def print_address(self):
         print(self.address._Address__city, self.address.pin, self.address.state)
         
class Address:
    def __init__(self,city,pin,state):
        self.__city = city
        self.pin = pin
        self.state = state
    def get_city(self):
        return self.__city

add1 = Address('rajgopal', 229219,'up')
cust = Customer('prasant','male',add1)

# %%
cust.print_address()
# Out:
# rajgopal 229219 up

# %%
class Customer:
     def __init__(self, name, gender,address):
         self.name = name
         self.gender = gender
         self.address = address
     def print_address(self):
         print(self.address.get_city(), self.address.pin, self.address.state)
     def edit_profile(self,new_name,new_city,new_pin, new_state):
         self.name = new_name
         self.address.edit_address(new_city,new_pin, new_state)
         
         
class Address:
    def __init__(self,city,pin,state):
        self.__city = city
        self.pin = pin
        self.state = state
    def get_city(self):
        return self.__city
    def edit_address(self,new_city,new_pin,new_state):
        self.__city = new_city
        self.pin = new_pin
        self.state = new_state

add1 = Address('rajgopal', 229219,'up')
cust = Customer('prasant','male',add1)
cust.edit_profile('prasant', 'mumbai',123456,'maharastra')
cust.print_address()
# Out:
# mumbai 123456 maharastra

# %%
cust.print_address()
# Out:
# rajgopal 229219 up

# %% [markdown]
# # aggregation class diagram
# ![image.png](attachment:980ef049-298a-4e14-aee8-cea1b48d5d26.png)

# %% [markdown]
# # inheritance
# ##### Inheritance is a mechanism in which one class (child/subclass) acquires the properties and behaviors (data and methods) of another class (parent/superclass)
# - It represents an “is-a” relationship
# - Promotes code reusability
# - Helps in extending existing functionality

# %%
class User:
    def __init__(self):
        self.name = 'prasant'
    def login(self):
        print('login')
class Student(User):
    
        
    def enroll(self):
        print('enroll into the course')

# %%
u = User()
s = Student()
print(s.name)
# Out:
# prasant

# %% [markdown]
# # what gets inherited?
# - constructor
# - non private attributes
# - non private methods
# ![image.png](attachment:b35728ab-d4a8-410a-ad04-2370a1a89d79.png)

# %%
class Phone:
    def __init__(self,price,brand,camera):
        print('inside phone constructor')
        self.price = price
        self.brand = brand
        self.camera = camera
    def buy(self):
        print("buying a phone")

# child class
class SmartPhone(Phone):      
    pass

s = SmartPhone(2000,'apple',13)
s.buy()
# Out:
# inside phone constructor
# buying a phone

# %%
class Phone:
    def __init__(self,price,brand,camera):
        print('inside phone constructor')
        self.price = price
        self.brand = brand
        self.camera = camera
    def buy(self):
        print("buying a phone")

# child class
class SmartPhone(Phone):      
    def __init__(self,os,ram):
        self.os = os
        self.ram = ram
        print("inside smartphone constructor")
    def buy(self):
        print('buying a smartphone')

s = SmartPhone('apple',13)
s.buy()
# Out:
# inside smartphone constructor
# buying a smartphone

# %%
# child can't access private members of the class
class Phone:
    def __init__(self,price,brand,camera):
        print('inside phone constructor')
        self.__price = price
        self.brand = brand
        self.camera = camera
    def show(self):
        print(self.__price)

# child class
class SmartPhone(Phone):      
    def check(self):
        print(self.__price)# private data of parent class

s = SmartPhone(2000,'apple',13)
print(s.brand)
s.check()
# Out:
# inside phone constructor
# apple
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[173], line 18
#      16 s = SmartPhone(2000,'apple',13)
#      17 print(s.brand)
# ---> 18 s.check()
#
# Cell In[173], line 14, in SmartPhone.check(self)
#      13 def check(self):
# ---> 14     print(self.__price)
#
# AttributeError: 'SmartPhone' object has no attribute '_SmartPhone__price'

# %%
# child can't access private members of the class
class Phone:
    def __init__(self,price,brand,camera):
        print('inside phone constructor')
        self.__price = price
        self.brand = brand
        self.camera = camera
    # this function is active as getter    
    def show(self):
        print(self.__price)

# child class
class SmartPhone(Phone):      
    def check(self):# private method of parent class
        print(self.__price)

s = SmartPhone(2000,'apple',13)
print(s.brand)
s.show() # after calling method it shows price
# Out:
# inside phone constructor
# apple
# 2000

# %%
# child can't access private members of the class
class Phone:
    def __init__(self,price,brand,camera):
        print('inside phone constructor')
        self.__price = price
        self.brand = brand
        self.camera = camera
    def __show(self): # private method
        print(self.__price)

# child class
class SmartPhone(Phone):      
    def check(self):# private method of parent class
        print(self.__price)

s = SmartPhone(2000,'apple',13)
print(s.brand)
s.__show()
# Out:
# inside phone constructor
# apple
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[179], line 18
#      16 s = SmartPhone(2000,'apple',13)
#      17 print(s.brand)
# ---> 18 s.__show()
#
# AttributeError: 'SmartPhone' object has no attribute '__show'

# %%
class Parent:

    def __init__(self,num):
        self.__num=num

    def get_num(self):
        return self.__num

class Child(Parent):

    def show(self):
        print("This is in child class")
        
son=Child(100)
print(son.get_num())
son.show()
# Out:
# 100
# This is in child class

# %%
class Parent:

    def __init__(self,num):
        self.__num=num

    def get_num(self):
        return self.__num

class Child(Parent):

    def __init__(self,val,num):
        self.__val=val

    def get_val(self):
        return self.__val
        
son=Child(100,10)
print("Child: Val:",son.get_val())
print("Parent: Num:",son.get_num())
# Out:
# Child: Val: 100
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[185], line 19
#      17 son=Child(100,10)
#      18 print("Child: Val:",son.get_val())
# ---> 19 print("Parent: Num:",son.get_num())
#
# Cell In[185], line 7, in Parent.get_num(self)
#       6 def get_num(self):
# ----> 7     return self.__num
#
# AttributeError: 'Child' object has no attribute '_Parent__num'

# %%
class A:
    def __init__(self):# here var1 and self.var1 are different 
        self.var1 = 100
    def display(self,var1):
        print("class A:", self.var1)
class B(A):
    def display2(self,var1):
        print("classB:",self.var1)
obj = B()
obj.display(200)
# Out:
# class A: 100

# %%
# method overriding
# constructor overloading
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")

s=SmartPhone(20000, "Apple", 13)

s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone

# %% [markdown]
# # super key

# %%
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")
        # syntax to call parent buy method
        super().buy()

s=SmartPhone(20000, "Apple", 13)

s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone
# Buying a phone

# %%
# super -> constuctor
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

class SmartPhone(Phone):
    def __init__(self, price, brand, camera, os, ram):
        print('Inside smartphone constructor')
        super().__init__(price, brand, camera)
        self.os = os
        self.ram = ram
        print ("Inside smartphone constructor")

s=SmartPhone(20000, "Samsung", 12, "Android", 2)

print(s.os)
print(s.brand)
# Out:
# Inside smartphone constructor
# Inside phone constructor
# Inside smartphone constructor
# Android
# Samsung

# %%
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")
        # syntax to call parent buy method
        

s=SmartPhone(20000, "Apple", 13)
s.super().buy()
s.buy()
# Out:
# Inside phone constructor
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[200], line 18
#      14         # syntax to call parent buy method
#      17 s=SmartPhone(20000, "Apple", 13)
# ---> 18 s.super().buy()
#      19 s.buy()
#
# AttributeError: 'SmartPhone' object has no attribute 'super'

# %%
# using super we can't acess attributes we can access only attributes of parent class
# super can't access variables
# super can't be use outside the class
# the parent has no access to the child class
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")
        # syntax to call parent buy method
        print(super().brand)

s=SmartPhone(20000, "Apple", 13)

s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[204], line 19
#      15         print(super().brand)
#      17 s=SmartPhone(20000, "Apple", 13)
# ---> 19 s.buy()
#
# Cell In[204], line 15, in SmartPhone.buy(self)
#      13 print ("Buying a smartphone")
#      14 # syntax to call parent buy method
# ---> 15 print(super().brand)
#
# AttributeError: 'super' object has no attribute 'brand'

# %%
class Parent:

    def __init__(self,num):
      self.__num=num

    def get_num(self):
      return self.__num

class Child(Parent):
  
    def __init__(self,num,val):
      super().__init__(num)
      self.__val=val

    def get_val(self):
      return self.__val
      
son=Child(100,200)
print(son.get_num())
print(son.get_val())
# Out:
# 100
# 200

# %%
class Parent:
    def __init__(self):
        self.num=100

class Child(Parent):

    def __init__(self):
        super().__init__()
        self.var=200
        
    def show(self):
        print(self.num)
        print(self.var)

son=Child()
son.show()
# Out:
# 100
# 200

# %%
class Parent:
    def __init__(self):
        self.__num=100

    def show(self):
        print("Parent:",self.__num)

class Child(Parent):
    def __init__(self):
        super().__init__()
        self.__var=10

    def show(self):
        print("Child:",self.__var)

obj=Child()
obj.show()
# Out:
# Child: 10

# %% [markdown]
# ### Types of Inheritance
#
# - Single Inheritance
# - Multilevel Inheritance
# - Hierarchical Inheritance
# - Multiple Inheritance(Diamond Problem)
# - Hybrid Inheritance
# ![image.png](attachment:f36ce300-ef50-47c0-b59a-9f48c9345749.png)![image.png](attachment:a81bec2a-693a-4830-9ca3-01b8e4503398.png)

# %%
# single inheritance
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

SmartPhone(1000,"Apple","13px").buy()
# Out:
# Inside phone constructor
# Buying a phone

# %%
# multilevel
class Product:
    def review(self):
        print ("Product customer review")

class Phone(Product):
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

s=SmartPhone(20000, "Apple", 12)

s.buy()
s.review()
# Out:
# Inside phone constructor
# Buying a phone
# Product customer review

# %%
# Hierarchical
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

class FeaturePhone(Phone):
    pass
SmartPhone(1000,"Apple","13px").buy()
FeaturePhone(10,"Lava","1px").buy()
# Out:
# Inside phone constructor
# Buying a phone
# Inside phone constructor
# Buying a phone

# %%
# Multiple
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class Product:
    def review(self):
        print ("Customer review")

class SmartPhone(Phone, Product):
    pass

s=SmartPhone(20000, "Apple", 12)

s.buy()
s.review()
# Out:
# Inside phone constructor
# Buying a phone
# Customer review

# %%
# the diamond problem
# https://stackoverflow.com/questions/56361048/what-is-the-diamond-problem-in-python-and-why-its-not-appear-in-python2
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class Product:
    def buy(self):
        print ("Product buy method")

# Method resolution order
class SmartPhone(Phone,Product):
    pass

s=SmartPhone(20000, "Apple", 12)

s.buy()
# Out:
# Inside phone constructor
# Buying a phone

# %%
class A:

    def m1(self):
        return 20

class B(A):

    def m1(self):
        return 30

    def m2(self):
        return 40

class C(B):
  
    def m2(self):
        return 20
obj1=A()
obj2=B()
obj3=C()
print(obj1.m1() + obj3.m1()+ obj3.m2())
# Out:
# 70

# %%
class A:

    def m1(self):
        return 20

class B(A):

    def m1(self):
        val=super().m1()+30
        return val

class C(B):
  
    def m1(self):
        val=self.m1()+20
        return val
obj=C()
print(obj.m1())
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[230], line 18
#      16         return val
#      17 obj=C()
# ---> 18 print(obj.m1())
#
# Cell In[230], line 15, in C.m1(self)
#      14 def m1(self):
# ---> 15     val=self.m1()+20
#      16     return val
#
# Cell In[230], line 15, in C.m1(self)
#      14 def m1(self):
# ---> 15     val=self.m1()+20
#      16     return val
#
#     [... skipping similar frames: C.m1 at line 15 (2974 times)]
#
# Cell In[230], line 15, in C.m1(self)
#      14 def m1(self):
# ---> 15     val=self.m1()+20
#      16     return val
#
# RecursionError: maximum recursion depth exceeded

# %% [markdown]
# ### Polymorphism
#
# - Method Overriding
# - Method Overloading
# - Operator Overloading

# %% [markdown]
# # method overloading
# ##### Method overloading is a feature that allows a class to have multiple methods with the same name but different parameters (type, number, or order)
# ##### python doesn't support method overloading

# %%
class Shape:# the code will more clean in reading
    def area(self, radius):
        return 3.14*radius*radius
    def area(self,l,b):
        return l*b
s = Shape()
s.area(2)
s.area(3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[239], line 9
#       7         return l*b
#       8 s = Shape()
# ----> 9 s.area(2)
#      10 s.area(3,4)
#
# TypeError: Shape.area() missing 1 required positional argument: 'b'

# %%
class Shape:

  def area(self,a,b=0):
    if b == 0:
      return 3.14*a*a
    else:
      return a*b

s = Shape()

print(s.area(2))
print(s.area(3,4))
# Out:
# 12.56
# 12

# %% [markdown]
# # Operator overloading
# ##### Operator overloading is a feature that allows operators to have different meanings based on the operands (objects) they are applied to.

# %%
'hello' + 'world'# example of operator overloading
# Out:
# 'helloworld'

# %%
4 + 5
# Out:
# 9
