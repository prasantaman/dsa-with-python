# %%
a = 10+1.0
print(a)
print(type(a))
# Out:
# 11.0
# <class 'float'>

# %%
# Mutable and Unmutable data types 
numbers = [1,3,4,5,6]
numbers.append(9)
print(numbers)
# Out:
# [1, 3, 4, 5, 6, 9]

# %%
numbers.index(5)
# Out:
# 3

# %%
numbers.remove(4)
print(numbers)
# Out:
# [1, 3, 5, 6, 9]

# %%
numbers.pop(1)# remove element according index
# Out:
# 3

# %%
print(numbers)
# Out:
# [1, 5, 6, 9]

# %%
numbers.extend([1,5])
numbers
# Out:
# [1, 5, 6, 9, 1, 5]

# %%
numbers.insert(2,10)
numbers
# Out:
# [1, 5, 10, 10, 6, 9, 1, 5]

# %%
numbers.sort()
numbers
# Out:
# [1, 1, 5, 5, 6, 9, 10, 10]

# %%
numbers.count(10)
# Out:
# 2

# %%
numbers.reverse()
numbers
# Out:
# [5, 1, 9, 6, 10, 10, 5, 1]

# %%
# set 
a = set()

# %%
a.add('science')

# %%
a
# Out:
# {'science'}

# %%
a.remove('science')

# %%
a
# Out:
# set()

# %%
a = (1,2,3)
b = (2,3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 3
#       1 a = (1,2,3)
#       2 b = (2,3,4)
# ----> 3 a-b
#
# TypeError: unsupported operand type(s) for -: 'tuple' and 'tuple'

# %%
# data types 
a = 10.0
print(type(a))
# Out:
# <class 'float'>

# %%
#type conversion 
calc = 10 
print(type(calc),calc)
# Out:
# <class 'int'> 10

# %%
data = bin(13)
print(bin(13))
# Out:
# 0b1101

# %%
int('1011',2)
# Out:
# 11

# %%
# string formating 
# loop 
count = 1
while count<=5:
    print(count)
    count += 1
# Out:
# 1
# 2
# 3
# 4
# 5
