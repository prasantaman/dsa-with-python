# %% [markdown]
# ### Namespaces
#
# A namespace is a space that holds names(identifiers).Programmatically speaking, namespaces are dictionary of identifiers(keys) and their objects(values)
#
# There are 4 types of namespaces:
# - Builtin Namespace
# - Global Namespace
# - Enclosing Namespace
# - Local Namespace

# %% [markdown]
# ### Scope and LEGB Rule
#
# A scope is a textual region of a Python program where a namespace is directly accessible.
#
# The interpreter searches for a name from the inside out, looking in the local, enclosing, global, and finally the built-in scope. If the interpreter doesn’t find the name in any of these locations, then Python raises a NameError exception.

# %%
# local and global -> same name
a = 2

def temp():
  # local var
  a = 3
  print(a)

temp()
print(a)
# Out:
# 3
# 2

# %%
a = 2

def temp():
  # local var
  print(a)

temp()
print(a)
# Out:
# 2
# 2

# %%
a = 2

def temp():
  # local var
  a +=1
  print(a)

temp()
print(a)# i can view of global varibale but can't change
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[9], line 8
#       5   a +=1
#       6   print(a)
# ----> 8 temp()
#       9 print(a)
#
# Cell In[9], line 5, in temp()
#       3 def temp():
#       4   # local var
# ----> 5   a +=1
#       6   print(a)
#
# UnboundLocalError: cannot access local variable 'a' where it is not associated with a value

# %%
# global created inside the local
def temp():
  # local var
  global a  
  a =1
  print(a)

temp()
print(a)
# Out:
# 1
# 1

# %%
def temp():
  # local var
  c = 3
  print(a)

temp()
print(c)
# Out:
# 1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 7
#       4   print(a)
#       6 temp()
# ----> 7 print(c)
#
# NameError: name 'c' is not defined

# %%
# function parameter is local
def temp(z):
    print(z)# local variable

a = 5
temp(5)
print(a)
# Out:
# 5
# 5

# %%
# built-in-scope
print('hello')
# Out:
# hello

# %%
import builtins
print(dir(builtins))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BaseExceptionGroup', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EncodingWarning', 'EnvironmentError', 'Exception', 'ExceptionGroup', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 
# ...

# %%
# renaming built-ins
l = [1,2,3]
max(l)
# Out:
# 3

# %%
l = [1,2,3]
def max():
    print('hello')

max(l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 5
#       2 def max():
#       3     print('hello')
# ----> 5 max(l)
#
# TypeError: max() takes 0 positional arguments but 1 was given

# %%
# enclosing scope
def outer():# here outer is a enclosing scope
    def inner():
        print('inner function')
    inner()
    print('outer function')

outer()
print('main program')
# Out:
# inner function
# outer function
# main program

# %%
def outer():
    
    def inner():
        
        print(d)
    inner()
    print('outer function')

outer()
print('main program')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 9
#       6     inner()
#       7     print('outer function')
# ----> 9 outer()
#      10 print('main program')
#
# Cell In[46], line 6, in outer()
#       3 def inner():
#       5     print(d)
# ----> 6 inner()
#       7 print('outer function')
#
# Cell In[46], line 5, in outer.<locals>.inner()
#       3 def inner():
# ----> 5     print(d)
#
# NameError: name 'd' is not defined

# %%
def outer():
    d = 1
    def inner():
        nonlocal d # not a good programming practice
        d+=1
        print(d)
    inner()
    print('outer function')

outer()
print('main program')
# Out:
# 2
# outer function
# main program

# %% [markdown]
# ### Decorators
#
# A decorator in python is a function that receives another function as input and adds some functionality(decoration) to and it and returns it.
#
# This can happen only because python functions are 1st class citizens.
#
# There are 2 types of decorators available in python
# - `Built in decorators` like `@staticmethod`, `@classmethod`, `@abstractmethod` and `@property` etc
# - `User defined decorators` that we programmers can create according to our needs

# %%
def modify(func,num):
    return func(num)

def square(num):
    return num**2

modify(square,2)
# Out:
# 4

# %%
# simple example
def my_decorator(func):
    def wrapper():
        print('prasant')
        func()
        print('sahu')
    return wrapper    
def hello():        
    print('hello')

a = my_decorator(hello)
a()
# Out:
# prasant
# hello
# sahu

# %% [markdown]
# ##### A closure is a function that remembers and can access variables from its outer (enclosing) function even after the outer function has finished execution.

# %%
def outer():
    x = 10
    
    def inner():
        print(x)   # x ko yaad rakhta hai
    
    return inner

f = outer()
f()   # Output: 10
# Out:
# 10

# %%
def my_decorator(func):
    def wrapper():
        print('prasant')
        func()
        print('sahu')
    return wrapper 

@my_decorator
def hello():        
    print('hello')
hello()
# Out:
# prasant
# hello
# sahu

# %%
import time
def timer(func):
    def wrapper():
        start = time.time()
        func()
        print('time taken by that func:', func.__name__,time.time()-start,'secs')
    return wrapper

@timer
def hello():
    print('hello')
    time.sleep(2)
hello()
# Out:
# hello
# time taken by that func: hello 2.0038506984710693 secs

# %%
import time
def timer(func):
    def wrapper():
        start = time.time()
        func()
        print('time taken by that func:', func.__name__,time.time()-start,'secs')
    return wrapper

@timer
def hello():
    print('hello')
    time.sleep(2)
@timer
def square():
    time.sleep(1)
    print(num**2)
square() # it means these kind of functionality works with only those functions whose don't need of input in functions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[87], line 17
#      15     time.sleep(1)
#      16     print(num**2)
# ---> 17 square()
#
# Cell In[87], line 5, in timer.<locals>.wrapper()
#       3 def wrapper():
#       4     start = time.time()
# ----> 5     func()
#       6     print('time taken by that func:', func.__name__,time.time()-start,'secs')
#
# Cell In[87], line 16, in square()
#      13 @timer
#      14 def square():
#      15     time.sleep(1)
# ---> 16     print(num**2)
#
# NameError: name 'num' is not defined

# %%
import time
def timer(func):
    def wrapper(*args):
        start = time.time()
        func(*args)
        print('time taken by that func:', func.__name__,time.time()-start,'secs')
    return wrapper

@timer
def hello():
    print('hello')
    time.sleep(2)
@timer
def square(num):
    time.sleep(1)
    print(num**2)
square(2)
# Out:
# 4
# time taken by that func: square 1.004939317703247 secs

# %%
def sanity_check(data_type):
  def outer_wrapper(func):
    def inner_wrapper(*args):
      if type(*args) == data_type:
        func(*args)
      else:
        raise TypeError('Ye datatype nai chalega')
    return inner_wrapper
  return outer_wrapper

@sanity_check(int)
def square(num):
  print(num**2)

@sanity_check(str)
def greet(name):
  print('hello',name)

square('hello')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[106], line 19
#      15 @sanity_check(str)
#      16 def greet(name):
#      17   print('hello',name)
# ---> 19 square('hello')
#
# Cell In[106], line 7, in sanity_check.<locals>.outer_wrapper.<locals>.inner_wrapper(*args)
#       5   func(*args)
#       6 else:
# ----> 7   raise TypeError('Ye datatype nai chalega')
#
# TypeError: Ye datatype nai chalega
