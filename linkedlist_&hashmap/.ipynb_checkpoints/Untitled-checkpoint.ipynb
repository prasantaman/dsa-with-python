# %%
# creation of linked list class 
class linkedlist:
    def __init__(self): 
        self.head = null # reference of first node

# %%
class node: 
    def __init__(self,data): 
        self.data = data
        self.next = None

# %%
class linkedlist: 
    def __init__(self): 
        self.head = None
    def insertatbeginning(self, data): 
        new_node = node(data)
        new_node.next = self.head 
        self.head = new_node 
    def print_list(self,data): 
        temp = self.head 
        while temp:
            print(temp.data, end = "->")
            temp = temp.next
        print(None)

# %%
ll = linkedlist()

ll.insertatbeginning(10)
ll.insertatbeginning(20)
ll.insertatbeginning(30)

ll.print_list()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 7
#       4 ll.insertatbeginning(20)
#       5 ll.insertatbeginning(30)
# ----> 7 ll.print_list()
#
# TypeError: linkedlist.print_list() missing 1 required positional argument: 'data'
