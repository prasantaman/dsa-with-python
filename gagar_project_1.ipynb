# %%
import re
import re

text = "My phone number is 9876543210"

result = re.search(r"\d+", text)

print(result.group())
# Out:
# 9876543210

# %%
text ="Veg Banana Walnut Cake 250 Gram"
result = re.search(r"\d+", text)
print(result.group())
# Out:
# 250

# %%
import pandas as pd
df = pd.read_excel('input.xlsx')

# %%
print(df)
# Out:
#                                Items  Quantity
# 0    Veg Banana Walnut Cake 250 Gram       1.0
# 1                        Stick Kulfi       2.0
# 2              Veg Gur Cake 250 Gram       1.0
# 3                   Dudh Ki Shikanji       2.0
# 4                     Rabri 100 Gram       4.0
# ..                               ...       ...
# 633                      Stick Kulfi       1.0
# 634                 Aloo Tikki Chaat       2.0
# 635                 Pineapple Pastry       1.0
# 636               Faluda Kesar Kulfi       1.0
# 637                      Stick Kulfi       1.0
#
# [638 rows x 2 columns]

# %%
item = str(row["Items"])
print(item)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 item = str(row["Items"])
#       2 print(item)
#
# NameError: name 'row' is not defined
